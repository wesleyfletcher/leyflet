# %%
import cbbpy.mens_scraper as cbb

# %%
ids = cbb.get_game_ids('2025-12-10')
ids
# Out:
# ['401825406',
#  '401824814',
#  '401825405',
#  '401819830',
#  '401818306',
#  '401826864',
#  '401830422',
#  '401826765',
#  '401830739',
#  '401828685',
#  '401826836',
#  '401826774',
#  '401823364',
#  '401822740',
#  '401820630',
#  '401820619',
#  '401817438',
#  '401817258',
#  '401817216',
#  '401817203',
#  '401817150',
#  '401812291',
#  '401826846',
#  '401826749',
#  '401829458',
#  '401829393',
#  '401828547',
#  '401827133',
#  '401826957',
#  '401824857',
#  '401823397',
#  '401827018',
#  '401813453',
#  '401823767',
#  '401823262',
#  '401823175',
#  '401828294',
#  '401824901']

# %%
len(cbb.get_game_pbp(ids[0]))
# Out:
# 391
